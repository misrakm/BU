# %% [markdown]
# # Week 12 - Milestone Two week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone Two is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Suppose you plot the number visitors to a museum over the seven days of a week; then again the following week.  Can you suggest the advantages and disadvantages of the following two ways of presenting the data?

# %% [markdown]
# ### Advantage of second over 1st Graph
# - the 2nd diagram is better way to represent as both diagram are on the same scale  but the first one has different y axis and even for x axis the limit is slightly bigger in the first diagram
#
# - Firstly, the scale is a big deal for me. Looking at both, it's clear the second diagram plays fair with the axes. They're both on the same page, scale-wise. The first one, though? The y-axis feels different, and even the x-axis stretches out a bit more. It makes it harder to get a real sense of comparison at a glance.
#
# - Then there's the clutter. The first diagram feels a bit overwhelming with all those axes going on. My eyes have to jump around to make sense of it all. The second one, with its single, clean pair of axes, is just so much easier to look at. It feels less noisy.
#
# - Because it's cleaner, the second diagram just clicks better in my head. I can interpret the data more easily without having to work so hard. It feels like less of a mental workout to understand what's going on.
#
# - Interestingly, the way the second diagram is presented gives me a better overall picture, more context. Maybe it's because I'm not distracted by the visual complexity of the first one, so the underlying story in the data comes through more clearly. I can compare the days of the week data easily.
#
#
# ### Problem with both Graphs:
# - The fact is, because neither diagram has a title, I'm left completely in the dark about what they're supposed to be showing, and without a legend, I can't decipher what each line represents, making both visualizations ultimately uninterpretable for me.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
time_series_0 = np.array([100, 110, 130, 120, 100, 90, 80])
time_series_1 = np.array([70, 90, 100, 100, 120, 110, 90])
fig, axs = plt.subplots(1, 2)
axs[0].plot(time_series_0)
axs[1].plot(time_series_1)
plt.subplots_adjust(wspace = 0)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %%
plt.plot(time_series_0)
plt.plot(time_series_1)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone Two rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 187-205 of the Storytelling With Data book as best you can. (Chapter Eight). You do not have to get the exact data values right, just the overall look and feel.

# %%
import matplotlib.pyplot as plt
import numpy as np

# X-coordinates
years_x_coordinates = [2008, 2009, 2010, 2011, 2012, 2013, 2014]

# y coordinates
y_line_a = np.array([400, 420, 450, 400, 280, 250, 225])
y_line_b = np.array([320, 380, 400, 300, 270, 240, 215])
y_line_c = np.array([None, None, None, 100, 180, 200, 205])
y_line_d = np.array([None, None, None, 180, 250, 220, 180])
y_line_e = np.array([None, None, None, None, None, 100, 180])

# let me find the index where the value starts
index_a = np.where(y_line_a != None)[0][0]
index_b = np.where(y_line_b != None)[0][0]
index_c = np.where(y_line_c != None)[0][0]
index_d = np.where(y_line_d != None)[0][0]
index_e = np.where(y_line_e != None)[0][0]

# add the line plot and then add the annotation at the start
plt.figure(figsize=(12, 7))
plt.plot(years_x_coordinates[index_a:], y_line_a[index_a:], color='gray')
plt.annotate('A', xy=(years_x_coordinates[index_a], y_line_a[index_a]+8), fontsize=14, fontweight='bold', color='gray')
plt.plot(years_x_coordinates[index_b:], y_line_b[index_b:], color='gray')
plt.annotate('B', xy=(years_x_coordinates[index_b], y_line_b[index_b]+8), fontsize=14, fontweight='bold', color='gray')
plt.plot(years_x_coordinates[index_c:], y_line_c[index_c:], color='gray')
plt.annotate('C', xy=(years_x_coordinates[index_c], y_line_c[index_c]+8), fontsize=14, fontweight='bold', color='gray')
plt.plot(years_x_coordinates[index_d:], y_line_d[index_d:], color='gray')
plt.annotate('D', xy=(years_x_coordinates[index_d], y_line_d[index_d]+8), fontsize=14, fontweight='bold', color='gray')
plt.plot(years_x_coordinates[index_e:], y_line_e[index_e:], color='gray')
plt.annotate('E', xy=(years_x_coordinates[index_e], y_line_e[index_e]+8), fontsize=14, fontweight='bold', color='gray')

#let me add the band for the recommendation range
plt.fill_between(years_x_coordinates, 190, 220, color='lightblue', alpha=0.5, label='Recommended range')

plt.title('Retail Price over Time - fig 8.19 Page 203', fontsize=18, weight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average price', fontsize=12)

plt.ylim(0, 500)
plt.yticks(np.arange(0, 551, 50))
plt.xlim(2008, 2014)

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
